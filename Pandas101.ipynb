# %% [markdown]
# <a href="https://colab.research.google.com/github/Tonry12/python_dataviz2023/blob/main/Pandas101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Meta data = Data that describtion data
#
# ใช้อธิบายช้อมูล
#
# ## CSV = Comma Separated Values
# ในการจะใส่ค่าแต่ละค่า จะใช้  comma ในการแย่ง

# %% [markdown]
# .csv = Comma Separated Values

# %% [markdown]
# data.go.th

# %% [markdown]
# # นำ Data เข้า
# - upload to colab  # กรณีใช้เเค่ครั้งเดียว
# - link with google drive

# %%
import pandas as pd

# %% [markdown]
# ## upload to colab

# %%
data0 = pd.read_csv('/content/ton.csv') #อ่านไฟล์โดยการนำ path มาวาง

# %%
data1 #ใช้ดูตารางทั้งหมด
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 0         งบประจำปี         0           62         11000000
# 1         งบประจำปี         0           62         11000000
# 2         งบประจำปี         0           62         11000000
# 3         งบประจำปี         0           62         11000000
# 4         งบประจำปี         0           62         11000000
# ..              ...       ...          ...              ...
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department                                   Core_budget_code  \
# 0        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 1        สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# ...

# %%
data1.head(5) #ดูหัวตาราง 5 rows แรก นับจาก 0-4
# Out:
#   Budget_resource  Issue_No  Fiscal_year  Department_code        Department  \
# 0       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 1       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 2       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 3       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 4       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
#
#                                     Core_budget_code Expenditure_category  \
# 0  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 1  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 2  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 3  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 4  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
#
# ...

# %%
data1.tail(5) #ดูท้ายตาราง 5 rows สุดท้าย
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# ...

# %%
data0.shape #ใช้ดูมิติของตาราง
# Out:
# (692, 9)

# %%
data1.describe() #ดูสถิติเชิงพรรณา มันจะขึ้นแค่คอลัมน์ที่เป็นตัวเลข
# Out:
#          Issue_No  Fiscal_year  Department_code  Approved_buget
# count  692.000000   692.000000     6.920000e+02    6.920000e+02
# mean     0.333815    64.543353     4.534202e+07    1.482811e+06
# std      0.474972     1.476149     1.303279e+07    2.464625e+06
# min      0.000000    62.000000     1.100000e+07    0.000000e+00
# 25%      0.000000    63.000000     5.013000e+07    4.100000e+05
# 50%      0.000000    65.000000     5.023000e+07    5.980000e+05
# 75%      1.000000    66.000000     5.036000e+07    1.628250e+06
# max      2.000000    66.000000     5.050000e+07    2.850000e+07

# %% [markdown]
# NaN = Not a Number

# %% [markdown]
# ## link with google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data1 = pd.read_csv('/content/drive/MyDrive/DataViz2023Data/ton.csv') #ใส่ path จาก drive
data1.head()
# Out:
#   Budget_resource  Issue_No  Fiscal_year  Department_code        Department  \
# 0       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 1       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 2       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 3       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
# 4       งบประจำปี         0           62         11000000  สำนักการระบายน้ำ
#
#                                     Core_budget_code Expenditure_category  \
# 0  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 1  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 2  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 3  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
# 4  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...              งบลงทุน
#
# ...

# %% [markdown]
# # ชี้ค่าในตาราง (indexing)

# %%
data1['Budget_resource']
# Out:
# 0        งบประจำปี
# 1        งบประจำปี
# 2        งบประจำปี
# 3        งบประจำปี
# 4        งบประจำปี
#           ...
# 687    งบเพิ่มเติม
# 688    งบเพิ่มเติม
# 689    งบเพิ่มเติม
# 690    งบเพิ่มเติม
# 691    งบเพิ่มเติม
# Name: Budget_resource, Length: 692, dtype: object

# %%
data1['Budget_resource'][687] #เป็นการชี้ดูว่าอยากได้ row ที่เท่าไหร่
# Out:
# 'งบเพิ่มเติม'

# %%
data1.columns
# Out:
# Index(['Budget_resource', 'Issue_No', 'Fiscal_year', 'Department_code',
#        'Department', 'Core_budget_code', 'Expenditure_category', 'Item_name',
#        'Approved_buget'],
#       dtype='object')

# %% [markdown]
# ##มุมมองตาราง df[column][row_m : row_n]##
# DF = dataframe

# %%
data1[['Approved_buget','Item_name','Department']] #การฟิวเตอร์ดูแค่ 3 column สามารถเลือกได้ว่าจะเอาคอลัมน์ไหนขึ้นก่อนหลังเองได้
# Out:
#      Approved_buget                                          Item_name  \
# 0           1193000        ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ
# 1           1100000  ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...
# 2           3075000          ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข
# 3           6240000  ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...
# 4           2685000  ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุ...
# ..              ...                                                ...
# 687         3686000                                 ขุดลอกคลองผักกะเฉด
# 688         2575000                            ขุดลอกคลองบึงทรายกองดิน
# 689          689000                                  ขุดลอกลำรางซาฟารี
# 690          464000                                ขุดลอกลำรางตาจันทร์
# 691         7578000          ขุดลอกคลองบางบอนต่อจากของเดิมถึงคลองนายผล
#
#                Department
# 0        สำนักการระบายน้ำ
# 1        สำนักการระบายน้ำ
# 2        สำนักการระบายน้ำ
# ...

# %%
data1[['Approved_buget','Item_name','Department']][6:11] #การฟิวเตอร์ดูแค่ 3 column และใจะเลือกมาแค่ row7 ถึง row12 (หรือ index 6-11)
# Out:
#     Approved_buget                                          Item_name  \
# 6           225400  ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระย...
# 7           452500  ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวาง...
# 8           447000  ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเ...
# 9           497000  ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำม...
# 10          189500                ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50
#
#               Department
# 6     สำนักงานเขตมีนบุรี
# 7     สำนักงานเขตมีนบุรี
# 8     สำนักงานเขตหนองจอก
# 9     สำนักงานเขตหนองจอก
# 10  สำนักงานเขตภาษีเจริญ

# %% [markdown]
# ## มุมมองแบบ Array ##

# %%
data1.iloc[0,0] # .iloc เปลี่ยนมุมมองเป็น np.arry  สนใจ cell ใน row ที่0 , คอลัมน์ ที่0
# Out:
# 'งบประจำปี'

# %%
data1.iloc[-6,5] #(ซึ่งมันก็คือ แถวก่อนสุดท้ายอยู่ 6 และคอลัมน์ที่ 5) ตามตารางด้านล่าง
# Out:
# nan

# %%
data1.tail(7)
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 685     งบเพิ่มเติม         1           66         50460000
# 686     งบเพิ่มเติม         1           66         50460000
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 685  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 686  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# ...

# %% [markdown]
# # Table Slicing
# ไม่ค่อยมีประสิทธิภาพ
# ต้องทราบพิกัด

# %%
data1.iloc[-20 :,7:10] #ต้องการ row =-20 ถึง rowสุดท้าย และคอลัมน์ที่ 7-10
# Out:
#                                              Item_name  Approved_buget
# 672  ขุดลอกลำกระโดงแยกคลองบางแวก (ตรงข้ามวัดบุณยประ...          472000
# 673  ขุดลอกลำกระโดงแยกคลองบางขี้แก้ง (หมู่บ้านเอเวอ...          492000
# 674                         ขุดลอกคลองแยกคลองตาเทียม 1          469000
# 675  ขุดลอกลำกระโดงระหว่างซอยเพชรเกษม 43 กับ ซอยเพช...          493000
# 676                          ขุดลอกคลองแยกคลองยายเพิ่ม          481000
# 677                    ขุดลอกลำกระโดงข้างหมู่บ้านวรนุช          492000
# 678                                    ขุดลอกคลองตาตี่          483000
# 679                        ขุดลอกลำกระโดงข้างเดอะมอลล์          462000
# 680                      ขุดลอกลำกระโดงข้างบ้านบางแค 2          499000
# 681                                   ขุดลอกลำรางตาเชย         3559000
# 682                              ขุดลอกลำรางไทยเอราวัณ         3494000
# 683                             ขุดลอกคลองหนึ่งตะวันตก         4330000
# ...

# %% [markdown]
#  ## Table Query

# %% [markdown]
# อยากได้รับอนุมัติงบเกิน 1 ล้านบาท
# ```df[logics]``` โดยที่ logic จะต้องมีสมาชิกเท่ากับจำนวนแถวของ df

# %%
small_df = data1.iloc[-5:,:]
small_df
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget
# 687                         ขุดลอกคลองผักกะเฉด         3686000
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000
# ...

# %%
T = True
F= False

# %%
small_df[[F,T,T,F,F]] #มันจะดึงตัวที่  2 กับ 3 ภายใน dataframe ที่ชื่อ small_df
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
#
#                Department Core_budget_code Expenditure_category  \
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
#
#                    Item_name  Approved_buget
# 688  ขุดลอกคลองบึงทรายกองดิน         2575000
# 689        ขุดลอกลำรางซาฟารี          689000

# %% [markdown]
# ###ปั้น list of logics จากตาราง pandas:###

# %%
small_df['Approved_buget'] < 1000000
# Out:
# 687    False
# 688    False
# 689     True
# 690     True
# 691    False
# Name: Approved_buget, dtype: bool

# %%
small_df[small_df['Approved_buget'] < 1000000]
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
#
#                Department Core_budget_code Expenditure_category  \
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
#
#                Item_name  Approved_buget
# 689    ขุดลอกลำรางซาฟารี          689000
# 690  ขุดลอกลำรางตาจันทร์          464000

# %% [markdown]
# ## Quiz3 อยากได้รายการที่ได้อนุมัติงบมากกว่า 1 ล้านบาท แต่ไม่เกิน 2 ล้าน##

# %%
data2= data1[(data1['Approved_buget'] > 1000000 ) & (data1['Approved_buget'] < 2000000)]
data2
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 0         งบประจำปี         0           62         11000000
# 1         งบประจำปี         0           62         11000000
# 5         งบประจำปี         0           62         11000000
# 22        งบประจำปี         0           63         11000000
# 25        งบประจำปี         0           63         11000000
# ..              ...       ...          ...              ...
# 660     งบเพิ่มเติม         1           66         50350000
# 662     งบเพิ่มเติม         1           66         50350000
# 665     งบเพิ่มเติม         1           66         50350000
# 666     งบเพิ่มเติม         1           66         50360000
# 670     งบเพิ่มเติม         1           66         50360000
#
#              Department                                   Core_budget_code  \
# 0      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 1      สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# ...

# %%
data2.describe() #ดูสถิติเชิงพรรณนา
# Out:
#          Issue_No  Fiscal_year  Department_code  Approved_buget
# count  132.000000   132.000000     1.320000e+02    1.320000e+02
# mean     0.363636    64.484848     4.373742e+07    1.457111e+06
# std      0.482878     1.550596     1.469685e+07    2.780676e+05
# min      0.000000    62.000000     1.100000e+07    1.015000e+06
# 25%      0.000000    63.000000     5.012000e+07    1.226250e+06
# 50%      0.000000    65.000000     5.022500e+07    1.399500e+06
# 75%      1.000000    66.000000     5.036000e+07    1.686500e+06
# max      1.000000    66.000000     5.050000e+07    1.992000e+06

# %% [markdown]
# # ~~~~~~Quiz 4~~~~
# 1. ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ร้านบาท
# 2. พื้นที่ และ จำนวนห้องนอนของบ้านที่แพงที่สุด
# 3. จำนวนที่จอดรถและห้องน้ำของบ้านที่ถูกที่สุด
# 4. ชนิดของบ้านที่แพงที่สุด
# 5. บ้านชนิดไหนมีปริมาณมากที่สุด

# %%
# 1. ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ร้านบาท
data1[(data1['price_min'] >=3000000) & (data1['price_min']<=5000000)].describe()
# Ans 3.928111e+06	 = 3.928111  ล้านบาท
# Out:
#          row_number  propertytype_id  area_total_min_wa  area_usable_min  \
# count   8943.000000      8943.000000        1066.000000      8148.000000
# mean   21153.925976      1285.383987          46.709559       138.785306
# std    12338.077057      4901.447720          18.555223        66.760066
# min        2.000000         1.000000           2.000000        20.100000
# 25%    10042.500000         1.000000          30.000000        96.000000
# 50%    21864.000000         2.000000          50.000000       145.000000
# 75%    32198.000000         3.000000          60.000000       178.000000
# max    42617.000000     20000.000000          99.000000       896.000000
#
#           price_min  count_airconditioner  count_elevator  \
# count  8.943000e+03            418.000000             0.0
# mean   3.922594e+06              2.653110             NaN
# std    5.847665e+05              1.128124             NaN
# min    3.000000e+06              1.000000             NaN
# ...

# %%
price_mean = data1[(data1['price_min'] >=3000000) & (data1['price_min']<=5000000)]['price_min'].mean()

# %%
print(f'ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบาท คือ {int(price_mean):,}')
# Out:
# ราคาเฉลี่ยของบ้านที่มีราคาระหว่าง 3-5 ล้านบาท คือ 3,922,594

# %%
#2.พื้นที่และจำนวนห้องนอนของบ้านที่แพงที่สุด
data1['price_min'].max()
# Out:
# 580000000.0

# %%
data1[data1['price_min']==580000000][['area_usable_min','count_room_bed']]
# Out:
#        area_usable_min  count_room_bed
# 33122           1182.0             3.0

# %%
data1[data1['price_min']==data1['price_min'].max()][['area_usable_min','count_room_bed','price_min']]
# Out:
#        area_usable_min  count_room_bed    price_min
# 33122           1182.0             3.0  580000000.0

# %%
data1[data1['price_min']==data1['price_min'].max()]

# %%
#3.จำนวนที่จอดรถและห้องน้ำที่ถูกที่สุด
data1['price_min'].min()
# Out:
# 100000.0

# %%
data1[data1['price_min']==100000][['count_parking','count_room_bath']]
# Out:
#        count_parking  count_room_bath
# 8640             NaN              1.0
# 11019            NaN              1.0
# 17941            NaN              1.0
# 30364            NaN              1.0

# %%
data1[data1['price_min']==data1['price_min'].min()][['propertytype_name_en','count_parking','count_room_bath','price_min']]
# Out:
#       propertytype_name_en  count_parking  count_room_bath  price_min
# 8640                 Condo            NaN              1.0   100000.0
# 11019                Condo            NaN              1.0   100000.0
# 17941                Condo            NaN              1.0   100000.0
# 30364                Condo            NaN              1.0   100000.0

# %%
# 4. ชนิดของบ้านที่แพงที่สุด
data1.describe()
data1[data1['price_min'] == 580000000]
# Ans Condo
# Out:
#        row_number     unittype_id     project_id    name_th  propertytype_id  \
# 33122        8629  unittype_37324  project_16305  Penthouse                2
#
#       propertytype_name_en propertytype_name_th  area_total_min_wa  \
# 33122                Condo                คอนโด                NaN
#
#        area_usable_min    price_min  ...  count_room_guest  \
# 33122           1182.0  580000000.0  ...               NaN
#
#        count_room_kitchen  count_room_living  count_room_maid  \
# 33122                 NaN                NaN              NaN
#
#        count_room_storage  count_room_utility         date_created  \
# 33122                 NaN                 NaN  2021-11-12 13:20:31
#
#               date_updated  source  \
# 33122  2020-10-14 00:55:50  baania
#
#                                             url_unittype
# 33122  https://baania.com/th/project/เดอะ-สุโขทัย-เรส...
#
# [1 rows x 27 columns]

# %%
# 4. ชนิดของบ้านที่แพงที่สุด
data1['propertytype_name_en'][data1['price_min'] == 580000000]
# Out:
# 33122    Condo
# Name: propertytype_name_en, dtype: object

# %%
data1[data1['price_min']==data1['price_min'].max()][['propertytype_name_en','price_min']]
# Out:
#       propertytype_name_en    price_min
# 33122                Condo  580000000.0

# %%
#5. บ้านชนิดไหนมีปริมาณมากที่สุด
data1['propertytype_name_en'].describe()
# Out:
# count              42625
# unique                11
# top       Detached House
# freq               17670
# Name: propertytype_name_en, dtype: object

# %% [markdown]
# ##Missing value##

# %% [markdown]
# $.isnull()$ ใช้ตรวจสอบว่าเป็น NaN หรือไม่

# %%
data1['Department'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 687    False
# 688    False
# 689    False
# 690    False
# 691    False
# Name: Department, Length: 692, dtype: bool

# %%
data1.isnull() #ถ้า T = เป็นค่าว่าง F = ไม่เป็นค่าว่าง
# Out:
#      Budget_resource  Issue_No  Fiscal_year  Department_code  Department  \
# 0              False     False        False            False       False
# 1              False     False        False            False       False
# 2              False     False        False            False       False
# 3              False     False        False            False       False
# 4              False     False        False            False       False
# ..               ...       ...          ...              ...         ...
# 687            False     False        False            False       False
# 688            False     False        False            False       False
# 689            False     False        False            False       False
# 690            False     False        False            False       False
# 691            False     False        False            False       False
#
#      Core_budget_code  Expenditure_category  Item_name  Approved_buget
# ...

# %%
data1.isnull().any() #ใช้ any() เพื่อเอาค่าความจริงในคอลัมน์มา ORกัน  ว่าในคอลัมน์ไหนบ้างที่มีค่าว่าง และ ไม่มีค่าว่าง
# Out:
# Budget_resource         False
# Issue_No                False
# Fiscal_year             False
# Department_code         False
# Department              False
# Core_budget_code         True
# Expenditure_category    False
# Item_name               False
# Approved_buget          False
# dtype: bool

# %%
data1.isnull().all() # มา AND กัน
# Out:
# Budget_resource         False
# Issue_No                False
# Fiscal_year             False
# Department_code         False
# Department              False
# Core_budget_code        False
# Expenditure_category    False
# Item_name               False
# Approved_buget          False
# dtype: bool

# %%
data1.isnull().any().any() #ใช้สรุปว่าใน dataframe ทั้งหมดของเรามีค่าว่างหรือเปล่า
# Out:
# True

# %% [markdown]
# ##การจัดการ Missing Value##
#
# - ลบ record ที่เป็น missing
# - แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default, category-unknown
# - ใช้ ค่าจาก columns อื่นๆ ช่วยประมาณค่า ค่าใน column ที่หายไป (regression, deep learning, etc.) เป็นการทำนายว่าช่องนั้นควรเป็นอะไร

# %% [markdown]
# ##การจัดการ NA##
# สามารถอ่านวิธีใช้ function ได้ที่ https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

# %%
data1.shape
# Out:
# (692, 9)

# %%
data1.dropna() #เมื่อทำการ drop na ทั้งหมดแล้ว จะทำให้ คอลัมน์หายไป 0 คอลัมน์ และหายไป 692-x = 266 rows
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 0         งบประจำปี         0           62         11000000
# 1         งบประจำปี         0           62         11000000
# 2         งบประจำปี         0           62         11000000
# 3         งบประจำปี         0           62         11000000
# 4         งบประจำปี         0           62         11000000
# ..              ...       ...          ...              ...
# 261       งบประจำปี         0           64         50500000
# 262       งบประจำปี         0           64         50500000
# 263       งบประจำปี         0           64         50500000
# 264       งบประจำปี         0           64         50500000
# 265       งบประจำปี         0           64         50500000
#
#             Department                                   Core_budget_code  \
# 0     สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# 1     สำนักการระบายน้ำ  12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี...
# ...

# %%
data1.dropna(subset=['Fiscal_year']).shape #การลบ missing แบบคนมีความรู้ เพราะ data หายไปแค่ 1%
# Out:
# (692, 9)

# %%
data1_1 = data1.dropna(subset=['Fiscal_year'])

# %%
data1_1.isnull().any()
# Out:
# Budget_resource         False
# Issue_No                False
# Fiscal_year             False
# Department_code         False
# Department              False
# Core_budget_code         True
# Expenditure_category    False
# Item_name               False
# Approved_buget          False
# dtype: bool

# %%
data1_1 = data1.dropna(subset=['Fiscal_year'],inplace=True) #เป็นการแทนที่ค่าว่าง

# %% [markdown]
# ##FillNA##

# %%
set(data1['Core_budget_code']) #เป็นการดู set ของข้อมูลในแต่ละเซลล์ของ column ว่ามีค่าไรบ้าง
# Out:
# {'-',
#  '12-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับน้ำท่วม',
#  '17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพัฒนากรุงเทพมหานคร',
#  '28-เงินสำรองค่าใช้จ่าย ในการพัฒนาเขต',
#  nan}

# %%
data1.fillna('-',inplace=True)

# %% [markdown]
# ##**HW3**##
# รายการที่แพงที่สุดและรายการที่ถูกที่สุด
#
# 1.   รายการที่แพงที่สุดและรายการที่ถูกที่สุด
# 2.   รายการขุดลอกคูคลองของ'สำนักงานเขตคลองสาน'และ 'สำนักงานเขตคลองสามวา'
# ,
# 3. จากข้อ2เขตไหนใช้งบประมาณมากกว่ากัน
# ,
# 4. Core buget ไหน(ประเภทรายการ เช่น เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับการน้ำท่วม ) มีค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด

# %%
import pandas as pd
data1.describe()
# Out:
#          Issue_No  Fiscal_year  Department_code  Approved_buget
# count  692.000000   692.000000     6.920000e+02    6.920000e+02
# mean     0.333815    64.543353     4.534202e+07    1.482811e+06
# std      0.474972     1.476149     1.303279e+07    2.464625e+06
# min      0.000000    62.000000     1.100000e+07    0.000000e+00
# 25%      0.000000    63.000000     5.013000e+07    4.100000e+05
# 50%      0.000000    65.000000     5.023000e+07    5.980000e+05
# 75%      1.000000    66.000000     5.036000e+07    1.628250e+06
# max      2.000000    66.000000     5.050000e+07    2.850000e+07

# %%
#ข้อ1 วิธีที่ 1 : รายการที่แพงที่สุดและรายการที่ถูกที่สุด
data1[(data1['Approved_buget'] == 28500000) | (data1['Approved_buget'] == 0)]
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 576     งบเพิ่มเติม         1           66         11000000
# 612     งบเพิ่มเติม         1           66         50180000
# 613     งบเพิ่มเติม         1           66         50180000
# 631     งบเพิ่มเติม         1           66         50240000
#
#                  Department Core_budget_code Expenditure_category  \
# 576        สำนักการระบายน้ำ              NaN              งบลงทุน
# 612       สำนักงานเขตธนบุรี              NaN              งบลงทุน
# 613       สำนักงานเขตธนบุรี              NaN              งบลงทุน
# 631  สำนักงานเขตราษฎร์บูรณะ              NaN              งบลงทุน
#
#                                              Item_name  Approved_buget
# 576  ขุดลอกคลองพระยาสุเรนทร์ จากคลองหกวาถึงคลองบางช...        28500000
# 612  ขุดลอกลำกระโดงอำนวยสุข จากคลองบางกอกใหญ่ถึงสุด...               0
# 613  ขุดลอกคลองแยกวัดประดู่ จากคลองบางกอกใหญ่ถึงคลอ...               0
# ...

# %%
#ข้อ2
data1[(data1['Department'] == 'สำนักงานเขตคลองสาน') | (data1['Department'] == 'สำนักงานเขตคลองสามวา')]
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 57        งบประจำปี         0           62         50170000
# 58        งบประจำปี         0           62         50170000
# 59        งบประจำปี         0           62         50170000
# 122       งบประจำปี         0           63         50170000
# 123       งบประจำปี         0           63         50170000
# 212       งบประจำปี         0           64         50170000
# 213       งบประจำปี         0           64         50170000
# 214       งบประจำปี         0           64         50170000
# 215       งบประจำปี         0           64         50170000
# 252       งบประจำปี         0           64         50460000
# 253       งบประจำปี         0           64         50460000
# 271       งบประจำปี         0           65         50170000
# 400     งบเพิ่มเติม         1           65         50460000
# 401     งบเพิ่มเติม         1           65         50460000
# 402     งบเพิ่มเติม         1           65         50460000
# ...

# %%
#ข้อ 3
KlongSan = data1[data1['Department'] =='สำนักงานเขตคลองสาน'][['Approved_buget']].sum()
KlongSam = data1[data1['Department'] =='สำนักงานเขตคลองสามวา'][['Approved_buget']].sum()

print(f'งบประมาณของสำนักงานเขตคลองสาน คือ {int(KlongSan):,} บาท')
print(f'งบประมาณของสำนักงานเขตคลองสามวา คือ {int(KlongSam):,} บาท')

print('')
result = KlongSan < KlongSam

if result is True:
  print('ดังนั้นงบประมาณสำนักงานเขตคลองสาน มากกว่า งบประมาณสำนักงานเขตคลองสามวา')
else :
  print('ดังนั้นงบประมาณสำนักงานเขตคลองสามวา มากกว่า งบประมาณสำนักงานเขตคลองสาน')
# Out:
# งบประมาณของสำนักงานเขตคลองสาน คือ 6,895,000 บาท
# งบประมาณของสำนักงานเขตคลองสามวา คือ 51,378,800 บาท
#
# ดังนั้นงบประมาณสำนักงานเขตคลองสามวา มากกว่า งบประมาณสำนักงานเขตคลองสาน

# %%
KlongSan1 = data1[data1['Core_budget_code'] =='สำนักงานเขตคลองสาน'][['Approved_buget']].sum()

# %%
#ข้อ 4 : Core buget ไหน(ประเภทรายการ เช่น เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายต่างๆ เกี่ยวกับการน้ำท่วม ) มีค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด
result4= data1.groupby('Core_budget_code')['Approved_buget'].aggregate(['mean'])
result4_1 = result4.groupby('Core_budget_code')['mean'].aggregate(['max'])
result4_1['max'].max()
re4 = result4_1[(result4_1['max'] == 1837500)]
re4.rename(columns = {'max':'ค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด'})
# Out:
#                                                     ค่าเฉลี่ยงบประมาณที่ถูกอนุมัติสูงที่สุด
# Core_budget_code
# 17-เงินสำรองจ่ายทั่วไป กรณีค่าใช้จ่ายเพื่อการพั...                                1837500.0

# %% [markdown]
# ##~~~~Quize รุ่นพี่~~~~##

# %%
##ข้อ2 : รายการขุดลอกคูคลองของ'สำนักงานเขตคลองสาน'และ 'สำนักงานเขตคลองสามวา'
df = pd.DataFrame(data1,columns=['Item_name','Department'])
df.set_index('Department', inplace=True)
result = df.loc[["สำนักงานเขตคลองสาน","สำนักงานเขตคลองสามวา"],['Item_name']]
result.rename(columns = {'Item_name' : 'รายการขุดลอกคูคลอง'})
# Out:
#                                                      รายการขุดลอกคูคลอง
# Department
# สำนักงานเขตคลองสาน                                   ขุดลอกคูน้ำสารภี 1
# สำนักงานเขตคลองสาน                              ขุดลอกคลองวัดทองเพลง\n
# สำนักงานเขตคลองสาน    ขุดลอกลำกระโดงชุมชนสองร้อยห้อง\nจากบริเวณบ้านเ...
# สำนักงานเขตคลองสาน    ขุดลอกคลองวัดทองธรรมชาติและคลองแยกคลองวัดทองธร...
# สำนักงานเขตคลองสาน                                     ขุดลอกคลองโรงปลา
# สำนักงานเขตคลองสาน                           ขุดลอกลำกระโดงซอยอิสรภาพ 3
# สำนักงานเขตคลองสาน         ขุดลอกคลองหลังวัดพิชัยญาติและคลองวัดน้อยเก่า
# สำนักงานเขตคลองสาน                                  ขุดลอกคลองพระยาเกษม
# สำนักงานเขตคลองสาน                      ขุดลอกคลองข้างโรงเรียนปทุมวิทยา
# สำนักงานเขตคลองสาน    ขุดลอกคลองวัดน้อยใหม่จากแยกบ้านแขกถึงคลองสมเด็...
# สำนักงานเขตคลองสาน    ขุดลอกคลองโรงหนัง จากคลองบางไส้ไก่ถึงแม่น้ำเจ้...
# สำนักงานเขตคลองสาน    ขุดลอกคลองข้างโรงน้ำแข็ง จากสุดระยะคลองถึงแม่น...
# ...

# %%
#ข้อ 3 : จากข้อ2เขตไหนใช้งบประมาณมากกว่ากัน
result7= data1.groupby('Department')['Approved_buget'].aggregate(['sum'])
re7 = result7.groupby('Department')['sum'].aggregate(['max'])
re7.rename(columns ={'max':'งบประมาณรวมที่มากที่สุด'} )[0:3][1:3]
# Out:
#                       งบประมาณรวมที่มากที่สุด
# Department
# สำนักงานเขตคลองสาน                    6895000
# สำนักงานเขตคลองสามวา                 51378800

# %%
#ข้อ1 วิธีที่ 2 : รายการที่แพงที่สุดและรายการที่ถูกที่สุด
result1= data1.groupby('Item_name')['Approved_buget'].aggregate(['max'])
re1 = result1[(result1['max'] == 28500000) | (result1['max'] == 0)]
re1.rename(columns = {'max' : 'รายการที่แพงที่สุดและถูกที่สุด'})
# Out:
#                                                     รายการที่แพงที่สุดและถูกที่สุด
# Item_name
# ขุดลอกคลองต้นโศกจากคลองราษฎร์บูรณะถึงคลองแจงร้อน                                 0
# ขุดลอกคลองพระยาสุเรนทร์ จากคลองหกวาถึงคลองบางชั...                        28500000
# ขุดลอกคลองแยกวัดประดู่ จากคลองบางกอกใหญ่ถึงคลอง...                               0
# ขุดลอกลำกระโดงอำนวยสุข จากคลองบางกอกใหญ่ถึงสุดเ...                               0

# %% [markdown]
# #### แทนด้วยค่ากลาง

# %%
data_covid['age']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-cc74bd3a1df2> in <cell line: 1>()
# ----> 1 data_covid['age']
#
# NameError: name 'data_covid' is not defined

# %%
data_covid['age'].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-bc33d562eba1> in <cell line: 1>()
# ----> 1 data_covid['age'].mean()
#
# NameError: name 'data_covid' is not defined

# %%
data_covid_fillwithmean = data_covid.fillna(value={'age':data_covid['age'].mean()})

# %%
data_covid_fillwithmean.isnull().any()

# %% [markdown]
# ### การวนลูป record ในตาราง  (```.iterrows```)

# %%
for row_i in range(len(data1)):
    print(data1.iloc[row_i,-2:])
    print('--------------------------------------------------------------------------')
# Out:
# Item_name         ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ
# Approved_buget                                        1193000
# Name: 0, dtype: object
# --------------------------------------------------------------------------
# Item_name         ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคช...
# Approved_buget                                              1100000
# Name: 1, dtype: object
# --------------------------------------------------------------------------
# Item_name         ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข
# Approved_buget                                      3075000
# Name: 2, dtype: object
# --------------------------------------------------------------------------
# Item_name         ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำ...
# Approved_buget                                              6240000
# Name: 3, dtype: object
# --------------------------------------------------------------------------
# ...

# %%
for row in data1.iterrows(): #ไม่จำเป็ต้องใช้ index ในการชี้แล้ว ใช้คำสั่งนี้จบๆ ได้เหมือนกับอันแรกด้วยจร้า
  print(row)
  print('----------------------------------------------------------------------------------')
# Out:
# เอาต์พุตของการสตรีมมีการตัดเหลือเพียง 5000 บรรทัดสุดท้าย
# Core_budget_code                                          -
# Expenditure_category                                งบลงทุน
# Item_name               ขุดลอกคลองสาธารณะข้างหมู่บ้านเทพนคร
# Approved_buget                                       495000
# Name: 237, dtype: object)
# ----------------------------------------------------------------------------------
# (238, Budget_resource                  งบประจำปี
# Issue_No                                 0
# Fiscal_year                             64
# Department_code                   50400000
# Department                สำนักงานเขตบางแค
# Core_budget_code                         -
# Expenditure_category               งบลงทุน
# Item_name               ขุดลอกคลองยายเพิ่ม
# Approved_buget                      439000
# Name: 238, dtype: object)
# ----------------------------------------------------------------------------------
# (239, Budget_resource                งบประจำปี
# ...

# %%
for row in data1.iterrows(): #ดึงมาเฉพาะบางส่วน
  print(row[1]['Fiscal_year'])
  print('----------------------------------------------------------------------------------')
# Out:
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ----------------------------------------------------------------------------------
# 62
# ...

# %% [markdown]
# ## การสร้าง columns เพิ่ม
# df['ชื่อ column ใหม่'] = list of data # list of data มีจำนวนสมาชิกเท่ากับจำนวน row ของตาราง

# %%
small_df['ผู้รับผิดชอบ'] = ['ลุงตู่','ลุงตู่','ลุงป้อม','ชัชชาติ','พิธา']
# Out:
# <ipython-input-24-0c6fae2e4445>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   small_df['ผู้รับผิดชอบ'] = ['ลุงตู่','ลุงตู่','ลุงป้อม','ชัชชาติ','พิธา']

# %%
small_df
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Core_budget_code Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              NaN              งบลงทุน
# 691     สำนักงานเขตบางบอน              NaN              งบลงทุน
#
#                                      Item_name  Approved_buget ผู้รับผิดชอบ
# 687                         ขุดลอกคลองผักกะเฉด         3686000       ลุงตู่
# ...

# %%
#การสร้างคอลัมน์ใหม่ที่เอา 3 คอลัมน์ มารวมกัน แล้วค่อยเอามาวนลูปกัน
new_column = list()
for row in data1.iterrows():
     new_col = f'{row[1]["Department"]}-{row[1]["Expenditure_category"]}-{row[1]["Item_name"]}'
     new_column.append(new_col)

# %%
new_column #จะได้ list ของคอลัมน์ใหม่ฮาฟฟวู่
# Out:
# ['สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองบางกะปิจากคลองสามเสนถึงคลองแสนแสบ',
#  'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองทรงกระเทียมจากคลองลาดพร้าวถึงถนนโชคชัย 4',
#  'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองเป้งจากคลองแสนแสบถึงซอยเจริญสุข',
#  'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองลำพังพวยจากถนนศรีบูรพาถึงสถานีสูบน้ำคลองลำพังพวยตอนคลองแสนแสบ',
#  'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกบึงรางเข้จากคลองพระยาราชมนตรีถึงถนนบางขุนเทียน-ชายทะเล',
#  'สำนักการระบายน้ำ-งบลงทุน-ขุดลอกคลองราษฎร์สามัคคีจากคลองทวีวัฒนาถึงคลองมหาศร',
#  'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางโต๊ะรอด ตั้งแต่คลองสองต้นนุ่นถึงระยะที่กำหนด แขวงมีนบุรี',
#  'สำนักงานเขตมีนบุรี-งบลงทุน-ขุดลอกลำรางเลียบคลองบึงขวาง ตั้งแต่คลองบึงขวางถึงระยะที่กำหนด แขวงมีนบุรี',
#  'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองลำแขก จากคลองลำปลาทิว \nถึงคลองลำตาเฟื่อง แขวงลำผักชี',
#  'สำนักงานเขตหนองจอก-งบลงทุน-ขุดลอกคลองอู่ตะเภา จากคลองลำนกแขวก\nถึงคลองลำมะขาม แขวงลำผักชี',
#  'สำนักงานเขตภาษีเจริญ-งบลงทุน-ขุดลอกลำกระโดงตรงข้ามซอยเพชรเกษม 50',
# ...

# %%
data1['desciption'] = new_column #คือการเอาคอลัมน์ใหม่ที่ชื่อ desciption ไปแทนใน new_column
data1 = data1.drop(axis=1,columns=["Department","Expenditure_category","Item_name"]) #โดยต้องลบคอลัมน์ 3 คอลัมน์ก่อน

# %% [markdown]
# ##การลบ column##

# %%
small_df.drop(axis=1,columns=['Core_budget_code']) #เป็นการลบ column ที่ชื่อ Core_budget_code แต่ว่าเรายังไม่แทนค่าลงในที่เดิม แค่เราปริ้นท์ออกมาเฉยๆจ้า
                                                                            # axis = 0,1 คือ แถว และ คอลัมน์ ตามลำดับ นั่นคือเราจะเลือกว่าเราจะลบแนวแถวหรือแนวคอลัมน์ นั่นเอง
# Out:
#     Budget_resource  Issue_No  Fiscal_year  Department_code  \
# 687     งบเพิ่มเติม         1           66         50460000
# 688     งบเพิ่มเติม         1           66         50460000
# 689     งบเพิ่มเติม         1           66         50460000
# 690     งบเพิ่มเติม         1           66         50460000
# 691     งบเพิ่มเติม         1           66         50500000
#
#                Department Expenditure_category  \
# 687  สำนักงานเขตคลองสามวา              งบลงทุน
# 688  สำนักงานเขตคลองสามวา              งบลงทุน
# 689  สำนักงานเขตคลองสามวา              งบลงทุน
# 690  สำนักงานเขตคลองสามวา              งบลงทุน
# 691     สำนักงานเขตบางบอน              งบลงทุน
#
#                                      Item_name  Approved_buget ผู้รับผิดชอบ
# 687                         ขุดลอกคลองผักกะเฉด         3686000       ลุงตู่
# 688                    ขุดลอกคลองบึงทรายกองดิน         2575000       ลุงตู่
# 689                          ขุดลอกลำรางซาฟารี          689000      ลุงป้อม
# ...

# %% [markdown]
# ### การวนลูป แบบมองตารางแพนด้าส์(pandas dataframe) เป็น numpy array  (```.iloc```)

# %%
for each_row in range(this_data.shape[0]):
    if (this_data.iloc[each_row,1] <= 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น'):  #each_row คือ ตัวเลข
        print(each_row)
        print(this_data.iloc[each_row,:])

# %% [markdown]
# ## Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
#
# **Hint**
# *   วนลูปหา index ของปี 2021
# *   ตัดตารางมาเฉพาะ ปี 2021

# %%
TF=list()
for each_row in data_covid.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        TF.append(True)
    else:
        TF.append(False)

data_covid[TF].head()

# %%
TF

# %% [markdown]
# ### HW กลุ่ม 2 || เลือกข้อมูลมาเฉพาะวัน announce_date เป็นวันที่ 1-20

# %% [markdown]
# # Function ตัวช่วยใน pandas

# %% [markdown]
# ### ```.describe()``` คำนวณค่าทางสถิติของข้อมูลที่เป็นตัวเลข

# %%
data_covid.describe()

# %% [markdown]
# ### ```.mean()``` คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean()

# %% [markdown]
# ### ```.isnull()```

# %%
data_covid.isnull()

# %% [markdown]
# # next
#
# *   ต่อตารางแกน X แกน y
# *   .groupby
# *   save table
